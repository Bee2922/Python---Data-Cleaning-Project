# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Desktop\dataset_olympics.csv")

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
--To view a summary of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
--Step 1 - Drop duplicates

# %%
df.drop_duplicates()
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
-- To save the new table as the dataframe

# %%
df = df.drop_duplicates()
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
-- Step 2 - Drop not useful columns and then save as the new dataset. For instance, drop the "city" column

# %%
df.drop(columns = "City")
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season            Sport  \
# ...

# %%
To save replace this data with the last one,

# %%
df = df.drop(columns = "City")
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season            Sport  \
# ...

# %%
---Using "Strip" to erase spaces, ... or any unwanted errors in each column starting with the Name column. 
First of all, view the Name column by using the code below. You can apply the below code to view the entire colums to detect where "strip" is needed

# %%
df["Name"]
# Out:
# 0                             A Dijiang
# 1                              A Lamusi
# 2                   Gunnar Nielsen Aaby
# 3                  Edgar Lindenau Aabye
# 4              Christine Jacoba Aaftink
#                       ...
# 69995                Stuart Fitzsimmons
# 69996                Stuart Fitzsimmons
# 69997    David Thomas "Dave" Fitzsimons
# 69998    David Thomas "Dave" Fitzsimons
# 69999                      Marek Fiurek
# Name: Name, Length: 69617, dtype: object

# %%
df["Name"].str.strip("...")
# Out:
# 0                             A Dijiang
# 1                              A Lamusi
# 2                   Gunnar Nielsen Aaby
# 3                  Edgar Lindenau Aabye
# 4              Christine Jacoba Aaftink
#                       ...
# 69995                Stuart Fitzsimmons
# 69996                Stuart Fitzsimmons
# 69997    David Thomas "Dave" Fitzsimons
# 69998    David Thomas "Dave" Fitzsimons
# 69999                      Marek Fiurek
# Name: Name, Length: 69617, dtype: object

# %%
--NOTE: To save the already stripped columns, using the formula df = df["Name"].str.strip("...") as used previously is not advisable as 
it would apply to the entire dataset, meaning that the other columns would be deleted and only the name column would remain. 
L or R can be placed right before "Strip" to take out whatever symbol placed by the text's left or right. 
Use the below code so the changes apply to just the columns

# %%
df["Name"] = df["Name"].str.strip("...")

# %%
-- To format the "Sex" column to ensure that both genders are standardised, we would replace the M in the sex column with the word 
Make and do same for the female gender. Use the below code

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
--To rename a column, for instance, the NOC column. Another way of ensuring that the new data replaces the former is to use the "inplace = True" code as used below as against using the df =

# %%
df.rename(columns = {'NOC':'Name of Country'}, inplace = True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12936\1406836009.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'NOC':'Name of Country'}, inplace = True)
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# ...

# %%
--To view the null values

# %%
df.isna()
# Out:
#           ID   Name    Sex    Age  Height  Weight   Team  Name of Country  \
# 0      False  False  False  False   False   False  False            False
# 1      False  False  False  False   False   False  False            False
# 2      False  False  False  False    True    True  False            False
# 3      False  False  False  False    True    True  False            False
# 4      False  False  False  False   False   False  False            False
# ...      ...    ...    ...    ...     ...     ...    ...              ...
# 69995  False  False  False  False    True    True  False            False
# 69996  False  False  False  False    True    True  False            False
# 69997  False  False  False  False   False   False  False            False
# 69998  False  False  False  False   False   False  False            False
# 69999  False  False  False  False   False   False  False            False
#
#        Games   Year  Season  Sport  Event  Medal
# ...

# %%
--To drop null values

# %%
df = df.dropna()
df
# Out:
#        index     ID                                  Name Sex   Age  Height  \
# 40        40     16              Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41        41     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 42        42     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 44        44     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 48        48     17               Paavo Johannes Aaltonen   M  28.0   175.0
# ...      ...    ...                                   ...  ..   ...     ...
# 69529  69912  35614                        Doris Fitschen   F  31.0   175.0
# 69569  69952  35632          James Edward "Ed" Fitzgerald   M  29.0   180.0
# 69591  69974  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   178.0
# 69600  69983  35651         Theresa Matauaina Fitzpatrick   F  21.0   168.0
# 69605  69988  35653                 Casey J. FitzRandolph   M  27.0   180.0
#
# ...

# %%
--Because the null values were removed, the index number will be messed up and needs to be reset

# %%
df.reset_index()
# Out:
#       index     ID                                  Name Sex   Age  Height  \
# 0        40     16              Juhamatti Tapio Aaltonen   M  28.0   184.0
# 1        41     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 2        42     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 3        44     17               Paavo Johannes Aaltonen   M  28.0   175.0
# 4        48     17               Paavo Johannes Aaltonen   M  28.0   175.0
# ...     ...    ...                                   ...  ..   ...     ...
# 7096  69529  35614                        Doris Fitschen   F  31.0   175.0
# 7097  69569  35632          James Edward "Ed" Fitzgerald   M  29.0   180.0
# 7098  69591  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   178.0
# 7099  69600  35651         Theresa Matauaina Fitzpatrick   F  21.0   168.0
# 7100  69605  35653                 Casey J. FitzRandolph   M  27.0   180.0
#
# ...

# %%
--Seeing that the index column is now duplicated, we have to drop a column
df.drop(columns = "index", inplace = True)

# %%
df
# Out:
#           ID                                  Name Sex   Age  Height  Weight  \
# 40        16              Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 48        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...      ...                                   ...  ..   ...     ...     ...
# 69529  35614                        Doris Fitschen   F  31.0   175.0    64.0
# 69569  35632          James Edward "Ed" Fitzgerald   M  29.0   180.0    79.0
# 69591  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   178.0    65.0
# 69600  35651         Theresa Matauaina Fitzpatrick   F  21.0   168.0    75.0
# 69605  35653                 Casey J. FitzRandolph   M  27.0   180.0    79.0
#
# ...

# %%
-- Finally, to save  the cleaned data as a csv file

# %%
df.to_csv("Cleaned_csv_file_Olympics_data_no_index.csv", index = False)

# %%
--To read the saved csv file

# %%
pd.read_csv("Cleaned_csv_file_Olympics_data_no_index.csv")
# Out:
#          ID                                  Name Sex   Age  Height  Weight  \
# 0        16              Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 1        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 2        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 3        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 4        17               Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...     ...                                   ...  ..   ...     ...     ...
# 7096  35614                        Doris Fitschen   F  31.0   175.0    64.0
# 7097  35632          James Edward "Ed" Fitzgerald   M  29.0   180.0    79.0
# 7098  35644  Benita P. Fitzgerald-Brown (-Mosley)   F  23.0   178.0    65.0
# 7099  35651         Theresa Matauaina Fitzpatrick   F  21.0   168.0    75.0
# 7100  35653                 Casey J. FitzRandolph   M  27.0   180.0    79.0
#
# ...
